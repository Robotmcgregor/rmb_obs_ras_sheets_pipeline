# %% [markdown]
# # ODK Aggregate processing pipeline.
#
# Copyright 2021 Robert McGregor

# %% [markdown]
# This notebook controls the processing of ODK Aggregate Result csv files and produces the following outputs:
# - observation sheet
# - ras sheet
# - downloads and renames photographs.

# %% [markdown]
# ### cd to the directory from the Anaconda/Miniconda terminal.
#
# cd E:\DENR\code\rangeland_monitoring\rmb_aggregate_processing

# %% [markdown]
# Depending on your system you may need to add "/d"
# i.e. cd /d E:\DENR\code\rangeland_monitoring\rmb_aggregate_processing

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Required packages:
# The ODK Aggregate processing pipeline requires the following package:
#
# - numpy
# - geopandas
# - datetime
# - os
# - argparse
# - sys
# - shutill
# - warnings
# - glob
# - xlsxwriter
#
# If you are using this notebook locally, you may need to install these packages using conda or pip. Uncomment one of the cells below by removing the hashtag('#') and run the cell by pressing **Shift+Enter**.

# %%
! conda list

# %% [markdown]
# ## Lets check the core packages versions in your conda environment.

# %%
import pandas; print(f"pandas: {pandas.__version__}")
import numpy; print(f"numpy: {numpy.__version__}")
import geopandas; print(f"geopandas: {geopandas.__version__}")
import argparse; print(f"argpass: {argparse.__version__}")
import xlsxwriter; print(f"xlsxwriter: {xlsxwriter.__version__}")
import selenium; print(f"selenium: {selenium.__version__}")

# %%
# If you do not have the required packages uncomment out the required line if you are on you local computer you will 
# need use external wifi (i.e. hotspot your phone)

#! conda install -c conda-forge numpy geopandas argparse xlsxwriter selenium
#! conda install -c conda-forge numpy
#! conda install -c conda-forge geopandas
#! conda install -c conda-forge argparse
#! conda install -c conda-forge xlsxwriter
#! conda install -c conda-forge selenium

# %% [markdown]
# ## Command arguments

# %% [markdown]
# - '-d', '--directory_odk', help = 'The directory containing ODK csv files.', default set to '\raw_odk'
# - '-x', '--export_dir', help = 'Directory path for outputs.', default set to 'Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs'
# - '-c', '--chrome_driver', help = 'File path for the chrome extension driver.', default set to "assets/chrome_driver/chrome_driver_v89_0_4389_23/chromedriver.exe"
# - '-r', '--remote_desktop', help = 'Working on the remote_desktop? - Enter remote_auto, remote, local or offline.', default set to 'remote' - see next cell for full explanation.
# - '-v', '--assets_veg_list_dir', help="Directory containing veg lists', default set to 'assets/veg_list'.
# - '-s', '--assets_shapefiles_dir', help='Directory containing shapefiles', default set to 'assets/shapefiles'
# - '-t', '--time_sleep', help='Time between odk aggregate actions -if lagging increase integer', default set to 20 - only required if ruuning remote_desktop as remote_auto
# - '-ht', '--html_dir', help='Directory containing html transect files. remote_desktop local or offline mode  requires the manual download of transect html tables', default='html_transect'
# - '-ver', '--version', help='ODK version being processed (e.g. v1, v2 etc.)', default='v1'
# - '-p', '--property_enquire', help="Enter the name of a single property you wish to process. (eg. PROPERTY NAME)", default is set to None (None - will process all sites).

# %% [markdown]
# ### Remote desktop command argument options

# %% [markdown]
#  - remote_auto = PGB-BAS14 server - will automate entire process - networking issues are currently causing this to crash - not recomended.
#  - remote = PGB-BAS14 server - will automate the process however, you will need to have downloads result csv files from ODK Aggregate - recommended.
#  - local = external computer conected to NTG internet requires odk csv files and will download photos - recommended.
#  - offline = external computer not conected to NTG internet - requires odk csv files and will not download photos - if required.

# %% [markdown]
# #### Known issues

# %% [markdown]
# - There are currently major issues with NTG Networking which are causing ODK to crash.
# - Due to the previously mentioned issue, saving transect data as an html/complete file over the network can also crash ODK Aggregate. As, such, all T4's have been approved for adm-accounts, allowing access to the remote server. Until such time that the network improved this script should only be used with remote_server set to 'remote', from within the remote server.

# %% [markdown]
# ### Check that you have connected to the project database

# %%
import geopandas as gpd
import os

path_parent = os.path.dirname(os.getcwd())
previous_visists_shapefile =  path_parent +  '\\assets\\shapefiles\\NT_StarTransect_20200713.shp'
gdf = gpd.read_file(previous_visists_shapefile)
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Do your results look like this?

# %% [markdown]
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# If yes, you are ready to run some code.
#
# If not, open this notebook from within the conda environment zonal, and try again.
#
# Still having issues? Contact Rob or Grant on Teams, sharing your screen to trouble shoot.

# %% [markdown]
# ## Run the RMB observatrion / ras sheet pipeline.

# %% [markdown]
# #### Change your working directory to code

# %%
import os
path_parent = os.path.dirname(os.getcwd())
code_dir =  path_parent +  '\\code'
os.chdir(code_dir)
print(os.getcwd())
# Out:
# E:\DENR\code\rangeland_monitoring\rmb_aggregate_processing\code

# %%
# %run step1_1_initiate_odk_processing_pipeline.py -h
# Out:
# usage: step1_1_initiate_odk_processing_pipeline.py [-h] [-d DIRECTORY_ODK]
#                                                    [-x EXPORT_DIR]
#                                                    [-c CHROME_DRIVER]
#                                                    [-r REMOTE_DESKTOP]
#                                                    [-v ASSETS_VEG_LIST_DIR]
#                                                    [-s ASSETS_SHAPEFILES_DIR]
#                                                    [-t TIME_SLEEP]
#                                                    [-ht HTML_DIR]
#                                                    [-ver VERSION]
#                                                    [-p PROPERTY_ENQUIRE]
#                                                    [-pd PASTORAL_DISTRICTS_DIRECTORY]
#
# Process raw RMB odk outputs -> csv, shapefiles observational sheets, and Ras
# sheets.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DIRECTORY_ODK, --directory_odk DIRECTORY_ODK
#                         The directory containing ODK csv files.
#   -x EXPORT_DIR, --export_dir EXPORT_DIR
#                         Directory path for outputs.
#   -c CHROME_DRIVER, --chrome_driver CHROME_DRIVER
#                         File path for the chrome extension driver.
#   -r REMOTE_DESKTOP, --remote_desktop REMOTE_DESKTOP
#                         Working on the remote_desktop? - Enter remote_auto,
#                         remote, local or offline.
#   -v ASSETS_VEG_LIST_DIR, --assets_veg_list_dir ASSETS_VEG_LIST_DIR
#                         Directory containing veg lists
#   -s ASSETS_SHAPEFILES_DIR, --assets_shapefiles_dir ASSETS_SHAPEFILES_DIR
#                         Directory containing shapefiles
#   -t TIME_SLEEP, --time_sleep TIME_SLEEP
#                         Time between odk aggregate actions -if lagging
#                         increase integer
#   -ht HTML_DIR, --html_dir HTML_DIR
#                         Directory containing html transect files (local or
#                         offline mode only
#   -ver VERSION, --version VERSION
#                         ODK version being processed (eg. v1, v2 etc.)
#   -p PROPERTY_ENQUIRE, --property_enquire PROPERTY_ENQUIRE
#                         Enter the name of of a single property you wish to
#                         process. (eg. Property Name)
#   -pd PASTORAL_DISTRICTS_DIRECTORY, --pastoral_districts_directory PASTORAL_DISTRICTS_DIRECTORY
#                         Enter path to the Pastoral_Districts directory in the
#                         Spatial/Working drive)

# %%
# %run step1_1_initiate_odk_processing_pipeline.py -r remote -d Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# Out:
# veg_list.xlsx located.
# pastoral_estate.shp located.
# NT_StarTransect_20200713.shp located.
# The following directory did not exist line 105:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946
# - located:  RMB_Star_Transect_v1_results.csv
# - in directory:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# --------------------------------------------------
# RMB_Star_Transect_v1_results.csv  located, initiating script..........
# BDS26A
# BDS17A
# BDS15A
# BDS19A
# BDS21A
# BDS16A
# BDS18A
# BDS23A
# BDS22A
# BDS25A
# BDS20A
# WDG14A
# WDG16A
# WDG17A
# WDG13A
# WDG15A
# MSK18A
# MSK19A
# MSK20A
# MSK17A
# MSK21A
# MSK23A
# MSK24A
# MSK25A
# MSK26A
# MDR17A
# MDR18A
# MDR20A
# MDR19A
# MDR21A
# MDR22A
# MDR27A
# MDR28A
# MDR30A
# MDR31A
# MDR33A
# MDR32A
# MDR24A
# MDR25A
# MDR26A
# MDR29A
# STL18A
# STL17A
# STL16A
# ANG18A
# STL13A
# STL14A
# ANG15A
# ANG14A
# MDR23A
# ANG23A
# ANG22A
# ANG21A
# ANG19A
# ANG20A
# ANG16A
# ANG17A
# MRK25A
# MRK26A
# MRK24A
# MRK23A
# MRK27A
# MRK22A
# MRK20A
# MRK21A
# MRK28A
# MRK19A
# MRK29A
# MRK30A
# MRK32A
# MRK31A
# MRK33A
# TGN12A
# TGN11A
# TGN09A
# TGN10A
# NPB14A
# NPB15A
# NPB16A
# NPB17A
# NPB18A
# NPB19A
# NPB20A
# NPB21A
# NPB22A
# NPB23A
# NPB24A
# NPB25A
# NWT16A
# NWT17A
# NWT15A
# NWT13A
# NWT14A
# NWT20A
# NWT19A
# NWT18A
# NWT21A
# NWT22A
# TGN08A
# CST11A
# CST12A
# CST14A
# Bond Springs
# Woodgreen
# Mount Skinner
# Mount Doreen
# Stirling
# Anningie
# Mount Riddock
# The Garden
# Napperby
# Narwietooma
# Coniston
# - located:  RMB_Integrated_v1_results.csv
# - in directory:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# --------------------------------------------------
# RMB_Integrated_v1_results.csv  located, initiating script..........
# - located:  RMB_Basal_Sweep_v1_results.csv
# - in directory:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# --------------------------------------------------
# RMB_Basal_Sweep_v1_results.csv  located, initiating script..........
# - located:  RMB_Woody_Thickening_v1_results.csv
# - in directory:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# --------------------------------------------------
# RMB_Woody_Thickening_v1_results.csv  located, initiating script..........
# - located:  RMB_Rapid_Assessment_RAS_v1_results.csv
# - in directory:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\raw_odk\rmcgr\Northern_Alice_Springs
# --------------------------------------------------
# RMB_Rapid_Assessment_RAS_v1_results.csv  located, initiating script..........
# __________________________________________________
# Anningie
# ANG01
# Ras sheet complete.
# __________________________________________________
# Anningie
# ANG04
# Ras sheet complete.
# __________________________________________________
# Anningie
# ANG06
# Ras sheet complete.
# __________________________________________________
# Anningie
# ANG07
# Ras sheet complete.
# __________________________________________________
# Anningie
# ANG10
# Ras sheet complete.
# ==================================================
# Patchy cloud 5 - 10% of sky
# Patchy cloud 5 - 10% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG14A', '12/08/2021 02:05:24 PM', 'BLANK']
# ['12/08/2021 02:05:24 PM', 'South', 'GDA94', -21.9926958, 133.4369365, -21.993215399999997, 133.4369067]
# __________________________________________________
# Anningie
# ANG14A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG15A', '12/08/2021 11:29:22 AM', 'BLANK']
# ['12/08/2021 11:29:22 AM', 'North east', 'GDA94', -21.8890378, 133.37669820000002, -21.8887853, 133.37718859999998]
# __________________________________________________
# Anningie
# ANG15A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG16A', '11/08/2021 04:08:46 PM', 'BLANK']
# ['11/08/2021 04:08:46 PM', 'South east', 'GDA94', -21.8371463, 133.30158079999998, -21.837463699999997, 133.302041]
# __________________________________________________
# Anningie
# ANG16A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG17A', '12/08/2021 08:35:00 AM', 'BLANK']
# ['12/08/2021 08:35:00 AM', 'South', 'GDA94', -21.7330051, 133.2726115, -21.7336149, 133.2725966]
# __________________________________________________
# Anningie
# ANG17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG18A', '11/08/2021 12:03:44 PM', 'BLANK']
# ['11/08/2021 12:03:44 PM', 'South', 'GDA94', -21.6777087, 133.12912749999998, -21.677589, 133.1294547]
# __________________________________________________
# Anningie
# ANG18A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG19A', '10/08/2021 03:12:30 PM', 'BLANK']
# ['10/08/2021 03:12:30 PM', 'North east', 'GDA94', -21.615846899999998, 133.0120566, -21.6162103, 133.0125017]
# __________________________________________________
# Anningie
# ANG19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG20A', '11/08/2021 08:16:50 AM', 'BLANK']
# ['11/08/2021 08:16:50 AM', 'South east', 'GDA94', -21.3742771, 133.0441552, -21.3745874, 133.0445671]
# __________________________________________________
# Anningie
# ANG20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG21A', '10/08/2021 11:31:20 AM', 'BLANK']
# ['10/08/2021 11:31:20 AM', 'North east', 'GDA94', -21.5185278, 132.9328, -21.5182814, 132.9333152]
# __________________________________________________
# Anningie
# ANG21A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG22A', '10/08/2021 08:21:05 AM', 'BLANK']
# ['10/08/2021 08:21:05 AM', 'South west', 'GDA94', -21.6221258, 132.9309756, -21.622363699999998, 132.9304663]
# __________________________________________________
# Anningie
# ANG22A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'ANG23A', '09/08/2021 02:04:55 PM', 'BLANK']
# ['09/08/2021 02:04:55 PM', 'South west', 'GDA94', -21.8757181, 133.0867245, -21.8753889, 133.0862486]
# __________________________________________________
# Anningie
# ANG23A
# Observation sheet complete.
# __________________________________________________
# Bond_Springs
# BDS01
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS03
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS04
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS06
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS07
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS08
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS09
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS10
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS11
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS12
# Ras sheet complete.
# __________________________________________________
# Bond_Springs
# BDS13
# Ras sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'BDS15A', '02/06/2021 11:13:57 AM', 'BLANK']
# ['02/06/2021 11:13:57 AM', 'North west', 'GDA94', -23.4393925, 133.94688119999998, -23.439130399999996, 133.9464186]
# __________________________________________________
# Bond_Springs
# BDS15A
# Observation sheet complete.
# ==================================================
# Patchy cloud 5 - 10% of sky
# Patchy cloud 5 - 10% of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS16A', '01/06/2021 02:03:37 PM', 'BLANK']
# ['01/06/2021 02:03:37 PM', 'North', 'GDA94', -23.478061, 133.9521973, -23.4775251, 133.9522541]
# __________________________________________________
# Bond_Springs
# BDS16A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'BDS17A', '02/06/2021 07:56:53 AM', 'BLANK']
# ['02/06/2021 07:56:53 AM', 'South', 'GDA94', -23.4194028, 134.0416746, -23.41996910000001, 134.0416091]
# __________________________________________________
# Bond_Springs
# BDS17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS18A', '02/06/2021 08:39:46 AM', 'BLANK']
# ['02/06/2021 08:39:46 AM', 'North west', 'GDA94', -23.4546264, 133.9869897, -23.454304699999998, 133.986522]
# __________________________________________________
# Bond_Springs
# BDS18A
# Observation sheet complete.
# ==================================================
# Patchy cloud 5 - 10% of sky
# Patchy cloud 5 - 10% of sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'BDS19A', '02/06/2021 01:28:46 PM', 'BLANK']
# ['02/06/2021 01:28:46 PM', 'South east', 'GDA94', -23.3282772, 133.8353544, -23.328626899999996, 133.8358779]
# __________________________________________________
# Bond_Springs
# BDS19A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS20A', '04/06/2021 08:14:04 AM', 'BLANK']
# ['04/06/2021 08:14:04 AM', 'North west', 'GDA94', -23.3648625, 133.7299588, -23.364542, 133.7295376]
# __________________________________________________
# Bond_Springs
# BDS20A
# Observation sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'BDS21A', '04/06/2021 09:16:59 AM', 'BLANK']
# ['04/06/2021 09:16:59 AM', 'West', 'GDA94', -23.407300199999998, 133.71944779999998, -23.407047100000003, 133.7189507]
# __________________________________________________
# Bond_Springs
# BDS21A
# Observation sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS22A', '03/06/2021 08:48:16 AM', 'BLANK']
# ['03/06/2021 08:48:16 AM', 'South west', 'GDA94', -23.472419600000002, 133.7488477, -23.4726234, 133.7483267]
# __________________________________________________
# Bond_Springs
# BDS22A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS23A', '02/06/2021 01:13:06 PM', 'BLANK']
# ['02/06/2021 01:13:06 PM', 'South east', 'GDA94', -23.4886683, 133.9018287, -23.4890294, 133.90231119999999]
# __________________________________________________
# Bond_Springs
# BDS23A
# Observation sheet complete.
# __________________________________________________
# Bond_Springs
# BDS24A
# Ras sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'BDS25A', '03/06/2021 02:03:26 PM', 'BLANK']
# ['03/06/2021 02:03:26 PM', 'North east', 'GDA94', -23.4955383, 133.7110041, -23.4952891, 133.7115711]
# __________________________________________________
# Bond_Springs
# BDS25A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'BDS26A', '01/06/2021 10:10:06 AM', 'BLANK']
# ['01/06/2021 10:10:06 AM', 'South', 'GDA94', -23.540926000000002, 133.9761323, -23.541480899999996, 133.97607309999998]
# __________________________________________________
# Bond_Springs
# BDS26A
# Observation sheet complete.
# __________________________________________________
# Bond_Springs
# RAS01
# Ras sheet complete.
# __________________________________________________
# Coniston
# CST06
# Ras sheet complete.
# __________________________________________________
# Coniston
# CST10
# Ras sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'CST11A', '27/02/2020 06:27:48 PM', 'BLANK']
# ['27/02/2020 06:27:48 PM', 'North east', 'GDA94', -21.9216594, 132.45406540000002, -21.921823, 132.4535656]
# __________________________________________________
# Coniston
# CST11A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'CST12A', '28/02/2020 11:21:35 AM', 'BLANK']
# ['28/02/2020 11:21:35 AM', 'South east', 'GDA94', -21.8947017, 132.6965041, -21.894476, 132.6960106]
# __________________________________________________
# Coniston
# CST12A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'CST14A', '19/10/2021 08:35:43 AM', 'BLANK']
# ['19/10/2021 08:35:43 AM', 'North west', 'GDA94', -21.9223795, 132.8591834, -21.9227535, 132.8597043]
# __________________________________________________
# Coniston
# CST14A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# ==================================================
# Coniston_CST15A  observational sheet will NOT be produced site name must match between transect and integrated result sheets.
# ==================================================
# __________________________________________________
# Mount_Doreen
# MDR07
# Ras sheet complete.
# __________________________________________________
# Mount_Doreen
# MDR10
# Ras sheet complete.
# __________________________________________________
# Mount_Doreen
# MDR16
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR17A', '24/07/2021 08:16:46 AM', 'BLANK']
# ['24/07/2021 08:16:46 AM', 'North east', 'GDA94', -22.573264399999996, 130.5981417, -22.573000600000004, 130.598687]
# __________________________________________________
# Mount_Doreen
# MDR17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR18A', '25/07/2021 08:19:40 AM', 'BLANK']
# ['25/07/2021 08:19:40 AM', 'North west', 'GDA94', -22.262297399999998, 130.5961968, -22.261965600000003, 130.595689]
# __________________________________________________
# Mount_Doreen
# MDR18A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR19A', '24/07/2021 03:06:23 PM', 'BLANK']
# ['24/07/2021 03:06:23 PM', 'North west', 'GDA94', -22.1765306, 130.7379262, -22.1762212, 130.7374311]
# __________________________________________________
# Mount_Doreen
# MDR19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR20A', '24/07/2021 01:20:11 PM', 'BLANK']
# ['24/07/2021 01:20:11 PM', 'North east', 'GDA94', -22.2540889, 130.7772707, -22.2538383, 130.7777774]
# __________________________________________________
# Mount_Doreen
# MDR20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR21A', '25/07/2021 11:25:10 AM', 'BLANK']
# ['25/07/2021 11:25:10 AM', 'North', 'GDA94', -21.95080410000001, 130.7074453, -21.950269600000002, 130.7074614]
# __________________________________________________
# Mount_Doreen
# MDR21A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR22A', '25/07/2021 03:31:42 PM', 'BLANK']
# ['25/07/2021 03:31:42 PM', 'North', 'GDA94', -22.160968399999998, 130.8416959, 'BLANK', 'BLANK']
# __________________________________________________
# Mount_Doreen
# MDR22A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR23A', '26/07/2021 08:17:59 AM', 'BLANK']
# ['26/07/2021 08:17:59 AM', 'South east', 'GDA94', -22.148135800000002, 130.8791159, -22.1484621, 130.879638]
# __________________________________________________
# Mount_Doreen
# MDR23A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR24A', '26/07/2021 10:29:50 AM', 'BLANK']
# ['26/07/2021 10:29:50 AM', 'North', 'GDA94', -22.1709784, 131.0425293, -22.1709898, 131.04252240000002]
# __________________________________________________
# Mount_Doreen
# MDR24A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR25A', '26/07/2021 01:31:37 PM', 'BLANK']
# ['26/07/2021 01:31:37 PM', 'North west', 'GDA94', -22.0832332, 131.0345602, -22.0829289, 131.0340303]
# __________________________________________________
# Mount_Doreen
# MDR25A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR26A', '26/07/2021 04:05:43 PM', 'BLANK']
# ['26/07/2021 04:05:43 PM', 'North east', 'GDA94', -22.088141399999998, 131.1141002, -22.087851999999998, 131.1147099]
# __________________________________________________
# Mount_Doreen
# MDR26A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR27A', '27/07/2021 08:27:14 AM', 'BLANK']
# ['27/07/2021 08:27:14 AM', 'South', 'GDA94', -22.0571414, 131.2393729, -22.0571715, 131.23932620000002]
# __________________________________________________
# Mount_Doreen
# MDR27A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR28A', '27/07/2021 10:49:48 AM', 'BLANK']
# ['27/07/2021 10:49:48 AM', 'South west', 'GDA94', -21.782741, 131.14548200000002, -21.7830146, 131.1449825]
# __________________________________________________
# Mount_Doreen
# MDR28A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR29A', '27/07/2021 02:32:16 PM', 'BLANK']
# ['27/07/2021 02:32:16 PM', 'South', 'GDA94', -22.1425482, 131.4266057, -22.143071799999998, 131.4265736]
# __________________________________________________
# Mount_Doreen
# MDR29A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR30A', '28/07/2021 09:56:56 AM', 'BLANK']
# ['28/07/2021 09:56:56 AM', 'South', 'GDA94', -22.2379548, 131.50492749999998, -22.2384603, 131.5049606]
# __________________________________________________
# Mount_Doreen
# MDR30A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR31A', '28/07/2021 01:19:14 PM', 'BLANK']
# ['28/07/2021 01:19:14 PM', 'South', 'GDA94', -22.3195056, 131.5176285, -22.3199968, 131.5175071]
# __________________________________________________
# Mount_Doreen
# MDR31A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR32A', '29/07/2021 08:46:15 AM', 'BLANK']
# ['29/07/2021 08:46:15 AM', 'North east', 'GDA94', -22.2869473, 131.4367527, -22.2867135, 131.437264]
# __________________________________________________
# Mount_Doreen
# MDR32A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'MDR33A', '28/07/2021 03:40:34 PM', 'BLANK']
# ['28/07/2021 03:40:34 PM', 'North west', 'GDA94', -22.3152186, 131.2508009, -22.3150076, 131.2502941]
# __________________________________________________
# Mount_Doreen
# MDR33A
# Observation sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK04
# Ras sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK05
# Ras sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK09
# Ras sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK10
# Ras sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK12
# Ras sheet complete.
# __________________________________________________
# Mount_Riddock
# MRK16
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK19A', '12/08/2021 07:36:30 AM', 'BLANK']
# ['12/08/2021 07:36:30 AM', 'North', 'GDA94', -22.9849702, 134.631251, -22.9855383, 134.6312034]
# __________________________________________________
# Mount_Riddock
# MRK19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK20A', '11/08/2021 09:48:57 AM', 'BLANK']
# ['11/08/2021 09:48:57 AM', 'South east', 'GDA94', -22.943376100000002, 134.6886755, -22.9430104, 134.6882646]
# __________________________________________________
# Mount_Riddock
# MRK20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK21A', '11/08/2021 11:19:35 AM', 'BLANK']
# ['11/08/2021 11:19:35 AM', 'North west', 'GDA94', -22.903839, 134.7976541, -22.9041141, 134.7981331]
# __________________________________________________
# Mount_Riddock
# MRK21A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK22A', '11/08/2021 07:46:32 AM', 'BLANK']
# ['11/08/2021 07:46:32 AM', 'North east', 'GDA94', -22.8412311, 134.7722975, -22.8413948, 134.77170680000003]
# __________________________________________________
# Mount_Riddock
# MRK22A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK23A', '10/08/2021 11:20:47 AM', 'BLANK']
# ['10/08/2021 11:20:47 AM', 'North west', 'GDA94', -22.9142316, 134.9439333, -22.9145134, 134.94440759999998]
# __________________________________________________
# Mount_Riddock
# MRK23A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK24A', '10/08/2021 10:00:23 AM', 'BLANK']
# ['10/08/2021 10:00:23 AM', 'North east', 'GDA94', -22.8929063, 135.0446532, -22.8932313, 135.0438466]
# __________________________________________________
# Mount_Riddock
# MRK24A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK25A', '09/08/2021 02:15:56 PM', 'BLANK']
# ['09/08/2021 02:15:56 PM', 'North east', 'GDA94', -22.926579, 135.13800780000003, -22.9263244, 135.1385201]
# __________________________________________________
# Mount_Riddock
# MRK25A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MRK26A', '10/08/2021 07:45:30 AM', 'BLANK']
# ['10/08/2021 07:45:30 AM', 'West', 'GDA94', -23.0340922, 135.12138330000002, -23.0338871, 135.1219299]
# __________________________________________________
# Mount_Riddock
# MRK26A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK27A', '10/08/2021 01:03:47 PM', 'BLANK']
# ['10/08/2021 01:03:47 PM', 'North east', 'GDA94', -22.9818211, 134.9122366, -22.9820922, 134.9117429]
# __________________________________________________
# Mount_Riddock
# MRK27A
# Observation sheet complete.
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK28A', '11/08/2021 01:09:31 PM', 'BLANK']
# ['11/08/2021 01:09:31 PM', 'South east', 'GDA94', -22.9869683, 134.7289393, -22.986866100000004, 134.72885569999997]
# __________________________________________________
# Mount_Riddock
# MRK28A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK29A', '12/08/2021 09:15:53 AM', 'BLANK']
# ['12/08/2021 09:15:53 AM', 'North', 'GDA94', -23.040264999999998, 134.83314130000002, -23.0408151, 134.83309580000002]
# __________________________________________________
# Mount_Riddock
# MRK29A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK30A', '12/08/2021 10:20:46 AM', 'BLANK']
# ['12/08/2021 10:20:46 AM', 'North', 'GDA94', -23.053207699999998, 134.7623944, -23.0537712, 134.7623889]
# __________________________________________________
# Mount_Riddock
# MRK30A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK31A', '13/08/2021 08:16:35 AM', 'BLANK']
# ['13/08/2021 08:16:35 AM', 'North west', 'GDA94', -23.0308827, 134.4869687, -23.031143, 134.4863706]
# __________________________________________________
# Mount_Riddock
# MRK31A
# Observation sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK32A', '13/08/2021 07:07:25 AM', 'BLANK']
# ['13/08/2021 07:07:25 AM', 'North east', 'GDA94', -23.0902913, 134.4984472, -23.0904754, 134.4981343]
# __________________________________________________
# Mount_Riddock
# MRK32A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MRK33A', '13/08/2021 09:32:03 AM', 'BLANK']
# ['13/08/2021 09:32:03 AM', 'South west', 'GDA94', -23.0086689, 134.41410990000003, -23.0084991, 134.4146519]
# __________________________________________________
# Mount_Riddock
# MRK33A
# Observation sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK01
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK03
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK04
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK07
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK14
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK15
# Ras sheet complete.
# __________________________________________________
# Mount_Skinner
# MSK16
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MSK17A', '22/07/2021 10:02:50 AM', 'BLANK']
# ['22/07/2021 10:02:50 AM', 'North east', 'GDA94', -22.236753399999998, 134.116272, -22.2370294, 134.1157627]
# __________________________________________________
# Mount_Skinner
# MSK17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MSK18A', '19/07/2021 11:11:50 AM', 'BLANK']
# ['19/07/2021 11:11:50 AM', 'West', 'GDA94', -22.155312300000002, 134.0895472, -22.1550832, 134.0900695]
# __________________________________________________
# Mount_Skinner
# MSK18A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MSK19A', '20/07/2021 08:19:32 AM', 'BLANK']
# ['20/07/2021 08:19:32 AM', 'South east', 'GDA94', -22.1831527, 134.14435600000002, -22.1828648, 134.1438801]
# __________________________________________________
# Mount_Skinner
# MSK19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MSK20A', '20/07/2021 10:27:17 AM', 'BLANK']
# ['20/07/2021 10:27:17 AM', 'North west', 'GDA94', -22.2173719, 134.2711839, -22.2176925, 134.27168490000003]
# __________________________________________________
# Mount_Skinner
# MSK20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MSK21A', '20/07/2021 01:16:28 PM', 'BLANK']
# ['20/07/2021 01:16:28 PM', 'North east', 'GDA94', -22.0372276, 134.28930119999998, -22.037615399999996, 134.2886471]
# __________________________________________________
# Mount_Skinner
# MSK21A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'MSK23A', '21/07/2021 08:20:10 AM', 'BLANK']
# ['21/07/2021 08:20:10 AM', 'North east', 'GDA94', -22.0773025, 134.50904740000001, -22.077544600000003, 134.50850400000002]
# __________________________________________________
# Mount_Skinner
# MSK23A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MSK24A', '21/07/2021 09:43:27 AM', 'BLANK']
# ['21/07/2021 09:43:27 AM', 'South', 'GDA94', -22.2194847, 134.505047, -22.219481899999998, 134.5049744]
# __________________________________________________
# Mount_Skinner
# MSK24A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MSK25A', '21/07/2021 12:55:33 PM', 'BLANK']
# ['21/07/2021 12:55:33 PM', 'South', 'GDA94', -22.291453100000002, 134.3469456, -22.2909478, 134.347011]
# __________________________________________________
# Mount_Skinner
# MSK25A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Hooper, David', 'Villiger, Rhonda', 'MSK26A', '22/07/2021 07:47:59 AM', 'BLANK']
# ['22/07/2021 07:47:59 AM', 'North east', 'GDA94', -22.2080655, 134.35733269999997, -22.208259299999998, 134.3567795]
# __________________________________________________
# Mount_Skinner
# MSK26A
# Observation sheet complete.
# __________________________________________________
# Napperby
# NPB01
# Ras sheet complete.
# __________________________________________________
# Napperby
# NPB04
# Ras sheet complete.
# __________________________________________________
# Napperby
# NPB11
# Ras sheet complete.
# __________________________________________________
# Napperby
# NPB12
# Ras sheet complete.
# __________________________________________________
# Napperby
# NPB13
# Ras sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NPB14A', '03/09/2021 03:06:41 PM', 'BLANK']
# ['03/09/2021 03:06:41 PM', 'South west', 'GDA94', -22.5022122, 132.6927598, -22.5025046, 132.6922654]
# __________________________________________________
# Napperby
# NPB14A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB15A', '06/09/2021 04:21:10 PM', 'BLANK']
# ['06/09/2021 04:21:10 PM', 'North', 'GDA94', -22.4696423, 132.8646149, -22.469081699999997, 132.86459720000002]
# __________________________________________________
# Napperby
# NPB15A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB16A', '04/09/2021 12:12:03 PM', 'BLANK']
# ['04/09/2021 12:12:03 PM', 'North west', 'GDA94', -22.3577821, 132.63517, -22.3574977, 132.6346601]
# __________________________________________________
# Napperby
# NPB16A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB17A', '04/09/2021 02:34:40 PM', 'BLANK']
# ['04/09/2021 02:34:40 PM', 'South', 'GDA94', -22.3271439, 132.6087201, -22.327684, 132.6086818]
# __________________________________________________
# Napperby
# NPB17A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NPB18A', '05/09/2021 08:33:18 AM', 'BLANK']
# ['05/09/2021 08:33:18 AM', 'North east', 'GDA94', -22.2780324, 132.653225, -22.277803600000002, 132.653747]
# __________________________________________________
# Napperby
# NPB18A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB19A', '06/09/2021 08:25:53 AM', 'BLANK']
# ['06/09/2021 08:25:53 AM', 'North', 'GDA94', -22.668996399999997, 132.8802389, -22.668411, 132.880251]
# __________________________________________________
# Napperby
# NPB19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB20A', '06/09/2021 10:03:56 AM', 'BLANK']
# ['06/09/2021 10:03:56 AM', 'North east', 'GDA94', -22.7609313, 132.8656604, -22.760712899999998, 132.8661907]
# __________________________________________________
# Napperby
# NPB20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB21A', '06/09/2021 12:00:11 PM', 'BLANK']
# ['06/09/2021 12:00:11 PM', 'South east', 'GDA94', -22.7953272, 132.8001772, -22.795604100000002, 132.800681]
# __________________________________________________
# Napperby
# NPB21A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NPB22A', '03/09/2021 10:18:48 AM', 'BLANK']
# ['03/09/2021 10:18:48 AM', 'South west', 'GDA94', -22.7440527, 132.6397298, -22.7438916, 132.6392205]
# __________________________________________________
# Napperby
# NPB22A
# Observation sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB23A', '02/09/2021 03:26:37 PM', 'BLANK']
# ['02/09/2021 03:26:37 PM', 'South west', 'GDA94', -23.016143399999997, 132.5440765, -23.0163799, 132.5435467]
# __________________________________________________
# Napperby
# NPB23A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NPB24A', '05/09/2021 03:11:42 PM', 'BLANK']
# ['05/09/2021 03:11:42 PM', 'North', 'GDA94', -22.5913355, 132.7573237, -22.590775100000002, 132.7573012]
# __________________________________________________
# Napperby
# NPB24A
# Observation sheet complete.
# ==================================================
# Dense cloud 70 - 100%
# Dense cloud 70 - 100%
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NPB25A', '04/09/2021 10:05:34 AM', 'BLANK']
# ['04/09/2021 10:05:34 AM', 'South east', 'GDA94', -22.5036981, 132.5802367, -22.5040111, 132.58069170000002]
# __________________________________________________
# Napperby
# NPB25A
# Observation sheet complete.
# __________________________________________________
# Narwietooma
# NWT04
# Ras sheet complete.
# __________________________________________________
# Narwietooma
# NWT06
# Ras sheet complete.
# __________________________________________________
# Narwietooma
# NWT07
# Ras sheet complete.
# __________________________________________________
# Narwietooma
# NWT08
# Ras sheet complete.
# __________________________________________________
# Narwietooma
# NWT10
# Ras sheet complete.
# __________________________________________________
# Narwietooma
# NWT12
# Ras sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NWT13A', '01/09/2021 02:40:42 PM', 'BLANK']
# ['01/09/2021 02:40:42 PM', 'South east', 'GDA94', -23.2415206, 132.35652679999998, -23.2417936, 132.3570018]
# __________________________________________________
# Narwietooma
# NWT13A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NWT14A', '02/09/2021 08:19:26 AM', 'BLANK']
# ['02/09/2021 08:19:26 AM', 'South east', 'GDA94', -23.1822977, 132.30563590000003, -23.1826638, 132.3061162]
# __________________________________________________
# Narwietooma
# NWT14A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NWT15A', '01/09/2021 11:47:04 AM', 'BLANK']
# ['01/09/2021 11:47:04 AM', 'South east', 'GDA94', -23.3118915, 132.418236, -23.3122238, 132.4187175]
# __________________________________________________
# Narwietooma
# NWT15A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NWT16A', '30/08/2021 01:01:31 PM', 'BLANK']
# ['30/08/2021 01:01:31 PM', 'South', 'GDA94', -23.274105399999996, 132.8113803, -23.274105399999996, 132.8113803]
# __________________________________________________
# Narwietooma
# NWT16A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NWT17A', '31/08/2021 11:36:50 AM', 'BLANK']
# ['31/08/2021 11:36:50 AM', 'South east', 'GDA94', -23.4471417, 132.7390615, -23.447456, 132.739506]
# __________________________________________________
# Narwietooma
# NWT17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NWT18A', '31/08/2021 09:57:11 AM', 'BLANK']
# ['31/08/2021 09:57:11 AM', 'South', 'GDA94', -23.3849, 132.710606, -23.3854395, 132.7105743]
# __________________________________________________
# Narwietooma
# NWT18A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NWT19A', '31/08/2021 08:16:50 AM', 'BLANK']
# ['31/08/2021 08:16:50 AM', 'North', 'GDA94', -23.3273155, 132.6568103, -23.3267984, 132.65687150000002]
# __________________________________________________
# Narwietooma
# NWT19A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NWT20A', '30/08/2021 03:46:03 PM', 'BLANK']
# ['30/08/2021 03:46:03 PM', 'South west', 'GDA94', -23.3354046, 132.5878159, -23.3356924, 132.5873262]
# __________________________________________________
# Narwietooma
# NWT20A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'NWT21A', '01/09/2021 08:32:27 AM', 'BLANK']
# ['01/09/2021 08:32:27 AM', 'South east', 'GDA94', -23.2768832, 132.5096821, -23.277182699999997, 132.51017620000002]
# __________________________________________________
# Narwietooma
# NWT21A
# Observation sheet complete.
# ==================================================
# Heavy cloud 40 - 70% of the sky
# Heavy cloud 40 - 70% of sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'NWT22A', '02/09/2021 11:42:03 AM', 'BLANK']
# ['02/09/2021 11:42:03 AM', 'South east', 'GDA94', -23.1956743, 132.4113584, -23.195997199999997, 132.4118259]
# __________________________________________________
# Narwietooma
# NWT22A
# Observation sheet complete.
# __________________________________________________
# Stirling
# STL03
# Ras sheet complete.
# __________________________________________________
# Stirling
# STL05
# Ras sheet complete.
# __________________________________________________
# Stirling
# STL06
# Ras sheet complete.
# __________________________________________________
# Stirling
# STL07
# Ras sheet complete.
# __________________________________________________
# Stirling
# STL09
# Ras sheet complete.
# __________________________________________________
# Stirling
# STL11
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'STL13A', '14/08/2021 08:58:11 AM', 'BLANK']
# ['14/08/2021 08:58:11 AM', 'North', 'GDA94', -21.6233892, 133.602099, -21.6228399, 133.6021845]
# __________________________________________________
# Stirling
# STL13A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'STL14A', '14/08/2021 11:57:43 AM', 'BLANK']
# ['14/08/2021 11:57:43 AM', 'North', 'GDA94', -21.3816116, 133.4011437, -21.381076500000002, 133.4009986]
# __________________________________________________
# Stirling
# STL14A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'STL16A', '15/08/2021 11:23:19 AM', 'BLANK']
# ['15/08/2021 11:23:19 AM', 'North east', 'GDA94', -21.837111899999996, 133.5968636, -21.836920199999998, 133.5973817]
# __________________________________________________
# Stirling
# STL16A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'STL17A', '13/08/2021 01:56:20 PM', 'BLANK']
# ['13/08/2021 01:56:20 PM', 'South west', 'GDA94', -21.8423797, 133.75147909999998, -21.8426035, 133.75093429999998]
# __________________________________________________
# Stirling
# STL17A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Mitchell, Debbie', 'Stevens, Kate', 'STL18A', '13/08/2021 11:00:22 AM', 'BLANK']
# ['13/08/2021 11:00:22 AM', 'South west', 'GDA94', -21.8696755, 134.1319995, -21.869944399999998, 134.1314933]
# __________________________________________________
# Stirling
# STL18A
# Observation sheet complete.
# __________________________________________________
# The_Garden
# TGN01
# Ras sheet complete.
# __________________________________________________
# The_Garden
# TGN05
# Ras sheet complete.
# __________________________________________________
# The_Garden
# TGN06
# Ras sheet complete.
# __________________________________________________
# The_Garden
# TGN07
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'TGN08A', '15/08/2021 08:30:58 AM', 'BLANK']
# ['15/08/2021 08:30:58 AM', 'South west', 'GDA94', -23.2492488, 134.348757, -23.249018, 134.3492737]
# __________________________________________________
# The_Garden
# TGN08A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'TGN09A', '14/08/2021 09:09:25 AM', 'BLANK']
# ['14/08/2021 09:09:25 AM', 'North', 'GDA94', -23.4077117, 134.36971880000002, -23.4082455, 134.3696822]
# __________________________________________________
# The_Garden
# TGN09A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'TGN10A', '14/08/2021 11:24:59 AM', 'BLANK']
# ['14/08/2021 11:24:59 AM', 'South', 'GDA94', -23.5080283, 134.2274495, -23.507495199999997, 134.2275205]
# __________________________________________________
# The_Garden
# TGN10A
# Observation sheet complete.
# ==================================================
# Patchy cloud 5 - 10% of sky
# Patchy cloud 5 - 10% of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'TGN11A', '13/08/2021 03:21:29 PM', 'BLANK']
# ['13/08/2021 03:21:29 PM', 'North', 'GDA94', -23.35574, 134.5409425, -23.355741300000002, 134.5409986]
# __________________________________________________
# The_Garden
# TGN11A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Villiger, Rhonda', 'Hooper, David', 'TGN12A', '13/08/2021 01:54:50 PM', 'BLANK']
# ['13/08/2021 01:54:50 PM', 'North', 'GDA94', -23.3203521, 134.5085671, -23.3209595, 134.5085535]
# __________________________________________________
# The_Garden
# TGN12A
# Observation sheet complete.
# __________________________________________________
# Woodgreen
# WDG01
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG04
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG05
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG06
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG07
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG08
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG09
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG10
# Ras sheet complete.
# __________________________________________________
# Woodgreen
# WDG12
# Ras sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'WDG13A', '14/07/2021 09:28:16 AM', 'BLANK']
# ['14/07/2021 09:28:16 AM', 'North', 'GDA94', -22.4514475, 134.3432085, -22.450903699999998, 134.3432592]
# __________________________________________________
# Woodgreen
# WDG13A
# ERROR -- transect direction error--
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'WDG14A', '13/07/2021 12:59:15 PM', 'BLANK']
# ['13/07/2021 12:59:15 PM', 'South west', 'GDA94', -22.543589, 134.3631855, -22.54380230000001, 134.362651]
# __________________________________________________
# Woodgreen
# WDG14A
# Observation sheet complete.
# ==================================================
# Clear sky
# Clear sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'WDG15A', '14/07/2021 02:54:44 PM', 'BLANK']
# ['14/07/2021 02:54:44 PM', 'South', 'GDA94', -22.394771, 134.3489311, -22.3953123, 134.3488173]
# __________________________________________________
# Woodgreen
# WDG15A
# Observation sheet complete.
# ==================================================
# Some cloud 1- 5 % of sky
# Some cloud 1 - 5 % of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'WDG16A', '15/07/2021 09:38:34 AM', 'BLANK']
# ['15/07/2021 09:38:34 AM', 'North', 'GDA94', -22.380579, 134.4090879, -22.3800375, 134.4090761]
# __________________________________________________
# Woodgreen
# WDG16A
# Observation sheet complete.
# ==================================================
# Moderate cloud 10 - 30% of sky
# Moderate cloud 10 - 30% of sky
# visit_vert_list1:  ['Stevens, Kate', 'Mitchell, Debbie', 'WDG17A', '15/07/2021 12:53:28 PM', 'BLANK']
# ...
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Coniston\Csv
# file_name:  Coniston_basal.csv
# values:  ['Northern_Alice', 'CST', 'Coniston', '2020', 'Northern_Alice', 'CST', 'Coniston', '2020']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Coniston\Csv
# file_name:  Coniston_integrated.csv
# values:  ['Northern_Alice', 'CST', 'Coniston', '2020', 'Northern_Alice', 'CST', 'Coniston', '2020']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Coniston\Csv
# file_name:  Coniston_ras.csv
# values:  ['Northern_Alice', 'CST', 'Coniston', '2020', 'Northern_Alice', 'CST', 'Coniston', '2020']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Coniston\Csv
# file_name:  Coniston_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Infrastructure\Field_Data\2020
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\CST_Coniston\Infrastructure\Field_Data\2020\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'MDR', 'Mount_Doreen', '2021', 'Northern_Alice', 'MDR', 'Mount_Doreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Doreen\Csv
# file_name:  Mount_Doreen_basal.csv
# values:  ['Northern_Alice', 'MDR', 'Mount_Doreen', '2021', 'Northern_Alice', 'MDR', 'Mount_Doreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Doreen\Csv
# file_name:  Mount_Doreen_integrated.csv
# values:  ['Northern_Alice', 'MDR', 'Mount_Doreen', '2021', 'Northern_Alice', 'MDR', 'Mount_Doreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Doreen\Csv
# file_name:  Mount_Doreen_ras.csv
# values:  ['Northern_Alice', 'MDR', 'Mount_Doreen', '2021', 'Northern_Alice', 'MDR', 'Mount_Doreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Doreen\Csv
# file_name:  Mount_Doreen_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\MDR_Mount_Doreen\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'MRK', 'Mount_Riddock', '2021', 'Northern_Alice', 'MRK', 'Mount_Riddock', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Riddock\Csv
# file_name:  Mount_Riddock_basal.csv
# values:  ['Northern_Alice', 'MRK', 'Mount_Riddock', '2021', 'Northern_Alice', 'MRK', 'Mount_Riddock', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Riddock\Csv
# file_name:  Mount_Riddock_integrated.csv
# values:  ['Northern_Alice', 'MRK', 'Mount_Riddock', '2021', 'Northern_Alice', 'MRK', 'Mount_Riddock', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Riddock\Csv
# file_name:  Mount_Riddock_ras.csv
# values:  ['Northern_Alice', 'MRK', 'Mount_Riddock', '2021', 'Northern_Alice', 'MRK', 'Mount_Riddock', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Riddock\Csv
# file_name:  Mount_Riddock_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\MRK_Mount_Riddock\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'MSK', 'Mount_Skinner', '2021', 'Northern_Alice', 'MSK', 'Mount_Skinner', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Skinner\Csv
# file_name:  Mount_Skinner_basal.csv
# values:  ['Northern_Alice', 'MSK', 'Mount_Skinner', '2021', 'Northern_Alice', 'MSK', 'Mount_Skinner', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Skinner\Csv
# file_name:  Mount_Skinner_integrated.csv
# values:  ['Northern_Alice', 'MSK', 'Mount_Skinner', '2021', 'Northern_Alice', 'MSK', 'Mount_Skinner', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Skinner\Csv
# file_name:  Mount_Skinner_ras.csv
# values:  ['Northern_Alice', 'MSK', 'Mount_Skinner', '2021', 'Northern_Alice', 'MSK', 'Mount_Skinner', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Mount_Skinner\Csv
# file_name:  Mount_Skinner_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\MSK_Mount_Skinner\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'NPB', 'Napperby', '2021', 'Northern_Alice', 'NPB', 'Napperby', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Napperby\Csv
# file_name:  Napperby_basal.csv
# values:  ['Northern_Alice', 'NPB', 'Napperby', '2021', 'Northern_Alice', 'NPB', 'Napperby', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Napperby\Csv
# file_name:  Napperby_integrated.csv
# values:  ['Northern_Alice', 'NPB', 'Napperby', '2021', 'Northern_Alice', 'NPB', 'Napperby', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Napperby\Csv
# file_name:  Napperby_ras.csv
# values:  ['Northern_Alice', 'NPB', 'Napperby', '2021', 'Northern_Alice', 'NPB', 'Napperby', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Napperby\Csv
# file_name:  Napperby_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\NPB_Napperby\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'NWT', 'Narwietooma', '2021', 'Northern_Alice', 'NWT', 'Narwietooma', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Narwietooma\Csv
# file_name:  Narwietooma_basal.csv
# values:  ['Northern_Alice', 'NWT', 'Narwietooma', '2021', 'Northern_Alice', 'NWT', 'Narwietooma', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Narwietooma\Csv
# file_name:  Narwietooma_integrated.csv
# values:  ['Northern_Alice', 'NWT', 'Narwietooma', '2021', 'Northern_Alice', 'NWT', 'Narwietooma', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Narwietooma\Csv
# file_name:  Narwietooma_ras.csv
# values:  ['Northern_Alice', 'NWT', 'Narwietooma', '2021', 'Northern_Alice', 'NWT', 'Narwietooma', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Narwietooma\Csv
# file_name:  Narwietooma_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\NWT_Narwietooma\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'STL', 'Stirling', '2021', 'Northern_Alice', 'STL', 'Stirling', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Stirling\Csv
# file_name:  Stirling_basal.csv
# values:  ['Northern_Alice', 'STL', 'Stirling', '2021', 'Northern_Alice', 'STL', 'Stirling', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Stirling\Csv
# file_name:  Stirling_integrated.csv
# values:  ['Northern_Alice', 'STL', 'Stirling', '2021', 'Northern_Alice', 'STL', 'Stirling', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Stirling\Csv
# file_name:  Stirling_ras.csv
# values:  ['Northern_Alice', 'STL', 'Stirling', '2021', 'Northern_Alice', 'STL', 'Stirling', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Stirling\Csv
# file_name:  Stirling_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\STL_Stirling\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'TGN', 'The_Garden', '2021', 'Northern_Alice', 'TGN', 'The_Garden', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\The_Garden\Csv
# file_name:  The_Garden_basal.csv
# values:  ['Northern_Alice', 'TGN', 'The_Garden', '2021', 'Northern_Alice', 'TGN', 'The_Garden', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\The_Garden\Csv
# file_name:  The_Garden_integrated.csv
# values:  ['Northern_Alice', 'TGN', 'The_Garden', '2021', 'Northern_Alice', 'TGN', 'The_Garden', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\The_Garden\Csv
# file_name:  The_Garden_ras.csv
# values:  ['Northern_Alice', 'TGN', 'The_Garden', '2021', 'Northern_Alice', 'TGN', 'The_Garden', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\The_Garden\Csv
# file_name:  The_Garden_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\TGN_The_Garden\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
# values:  ['Northern_Alice', 'WDG', 'Woodgreen', '2021', 'Northern_Alice', 'WDG', 'Woodgreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Woodgreen\Csv
# file_name:  Woodgreen_basal.csv
# values:  ['Northern_Alice', 'WDG', 'Woodgreen', '2021', 'Northern_Alice', 'WDG', 'Woodgreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Woodgreen\Csv
# file_name:  Woodgreen_integrated.csv
# values:  ['Northern_Alice', 'WDG', 'Woodgreen', '2021', 'Northern_Alice', 'WDG', 'Woodgreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Woodgreen\Csv
# file_name:  Woodgreen_ras.csv
# values:  ['Northern_Alice', 'WDG', 'Woodgreen', '2021', 'Northern_Alice', 'WDG', 'Woodgreen', '2021']
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Data\Processed_Odk
# orig_file_path:  Z:\Scratch\Zonal_Stats_Pipeline\rmb_aggregate_processing\outputs\rmcgr_20211028_0946\prop_output\Woodgreen\Csv
# file_name:  Woodgreen_star_transect.csv
# star transect located
# output_file_path :  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Infrastructure\Field_Data
# file_year_path3:  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Infrastructure\Field_Data\2021
# shp_path 263:  U:\Pastoral_Districts\Northern_Alice\WDG_Woodgreen\Infrastructure\Field_Data\2021\Raw\offset_mon_points\Shp
